# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %config IPCompleter.greedy=True

# %%
listings = pd.read_csv('DatosValencia/listings.csv')

listings.head()
# Out:
#        id                                       name  host_id       host_name  \
# 0   48154              Precioso apartamento con wifi   219476         Antonio
# 1  136378         Old City Charm with Modern Comfort   591197           Elisa
# 2  149715  1900 Style Valencian Beach  Home for 10px     5947  Susana Barbara
# 3  165971                   ★ Architectural touch! ★   791187            Inés
# 4  182221         Apartments Calatrava City Valencia  1315567          Chiara
#
#   neighbourhood_group        neighbourhood  latitude  longitude  \
# 0           LA SAIDIA             MORVEDRE  39.48375   -0.37502
# 1        CIUTAT VELLA            EL MERCAT  39.47358   -0.37815
# 2    POBLATS MARITIMS  CABANYAL-CANYAMELAR  39.46746   -0.32813
# 3           EXTRAMURS           LA ROQUETA  39.46790   -0.38206
# 4      CAMINS AL GRAU                AIORA  39.46343   -0.34325
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9596 entries, 0 to 9595
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              9596 non-null   int64
#  1   name                            9596 non-null   object
#  2   host_id                         9596 non-null   int64
#  3   host_name                       9596 non-null   object
#  4   neighbourhood_group             9596 non-null   object
#  5   neighbourhood                   9596 non-null   object
#  6   latitude                        9596 non-null   float64
#  7   longitude                       9596 non-null   float64
#  8   room_type                       9596 non-null   object
#  9   price                           9082 non-null   float64
#  10  minimum_nights                  9596 non-null   int64
#  11  number_of_reviews               9596 non-null   int64
# ...

# %%
# listings detailed
listings_det = pd.read_csv("DatosValencia/listings.csv.gz")

# %%
listings_det.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0   48154   https://www.airbnb.com/rooms/48154  20240622134440   2024-06-22
# 1  136378  https://www.airbnb.com/rooms/136378  20240622134440   2024-06-23
# 2  149715  https://www.airbnb.com/rooms/149715  20240622134440   2024-06-23
# 3  165971  https://www.airbnb.com/rooms/165971  20240622134440   2024-06-22
# 4  182221  https://www.airbnb.com/rooms/182221  20240622134440   2024-06-23
#
#         source                                       name  \
# 0  city scrape              Precioso apartamento con wifi
# 1  city scrape         Old City Charm with Modern Comfort
# 2  city scrape  1900 Style Valencian Beach  Home for 10px
# 3  city scrape                   ★ Architectural touch! ★
# 4  city scrape         Apartments Calatrava City Valencia
#
#                                          description  \
# 0  Second floor on a farm from the late 19th cent...
# ...

# %%
listings_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9596 entries, 0 to 9595
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            9596 non-null   int64
#  1   listing_url                                   9596 non-null   object
#  2   scrape_id                                     9596 non-null   int64
#  3   last_scraped                                  9596 non-null   object
#  4   source                                        9596 non-null   object
#  5   name                                          9596 non-null   object
#  6   description                                   9302 non-null   object
#  7   neighborhood_overview                         4728 non-null   object
#  8   picture_url                                   9596 non-null   object
# ...

# %%
reviews = pd.read_csv("DatosValencia/reviews.csv")

# %%
reviews.head()
# Out:
#    listing_id        date
# 0       48154  2010-10-12
# 1       48154  2010-11-28
# 2       48154  2011-03-01
# 3       48154  2011-03-08
# 4       48154  2011-04-05

# %%
reviews.info()

# It tells us the date on which each review was posted for each property, not very useful
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409547 entries, 0 to 409546
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   listing_id  409547 non-null  int64
#  1   date        409547 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 6.2+ MB

# %%
reviews_det = pd.read_csv("DatosValencia/reviews.csv.gz")

# %%
reviews_det.head()
# Out:
#    listing_id      id        date  reviewer_id    reviewer_name  \
# 0       48154  117554  2010-10-12       180238           Martha
# 1       48154  145645  2010-11-28       204240             Mark
# 2       48154  190572  2011-03-01       258565         Domenico
# 3       48154  195081  2011-03-08       213496  Romina & Martín
# 4       48154  218435  2011-04-05       340330            Jenna
#
#                                             comments
# 0  Toni's place was perfect in so many ways.  It ...
# 1  Awesome stay!! We'd recommend Toni's apartment...
# 2  really nice house in a wonderfull position! yo...
# 3  Apartamento muy agradable, al igual que su pro...
# 4  Was a great apartment, easy access to the site...

# %%
reviews_det.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409547 entries, 0 to 409546
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   listing_id     409547 non-null  int64
#  1   id             409547 non-null  int64
#  2   date           409547 non-null  object
#  3   reviewer_id    409547 non-null  int64
#  4   reviewer_name  409547 non-null  object
#  5   comments       409532 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 18.7+ MB

# %%
# in our case we are not going to use these reviews.
# it could be interesting for other projects that use NLP or similar

# %%
calendar = pd.read_csv("DatosValencia/calendar.csv.gz")

# %%
calendar.head()
# Out:
#    listing_id        date available   price  adjusted_price  minimum_nights  \
# 0       48154  2024-06-22         f  $75.00             NaN             3.0
# 1       48154  2024-06-23         f  $75.00             NaN             3.0
# 2       48154  2024-06-24         f  $75.00             NaN             5.0
# 3       48154  2024-06-25         f  $75.00             NaN             5.0
# 4       48154  2024-06-26         f  $75.00             NaN             5.0
#
#    maximum_nights
# 0            25.0
# 1            25.0
# 2            22.0
# 3            22.0
# 4            22.0

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3502526 entries, 0 to 3502525
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   listing_id      int64
#  1   date            object
#  2   available       object
#  3   price           object
#  4   adjusted_price  float64
#  5   minimum_nights  float64
#  6   maximum_nights  float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 187.1+ MB

# %%
calendar.date.min()
# Out:
# '2024-06-22'

# %%
# It doesn't look like we're going to use this information, it's basically the availability of each one

# %%
pd.read_csv("DatosValencia/neighbourhoods.csv")
# Out:
#    neighbourhood_group   neighbourhood
# 0              ALGIROS    CIUTAT JARDI
# 1              ALGIROS     LA CARRASCA
# 2              ALGIROS       L'AMISTAT
# 3              ALGIROS   LA VEGA BAIXA
# 4              ALGIROS  L'ILLA PERDUDA
# ..                 ...             ...
# 83     QUATRE CARRERES     MONT-OLIVET
# 84     QUATRE CARRERES      NA ROVELLA
# 85            RASCANYA     ELS ORRIOLS
# 86            RASCANYA    SANT LLORENS
# 87            RASCANYA       TORREFIEL
#
# [88 rows x 2 columns]

# %%
pd.read_json("DatosValencia/neighbourhoods.geojson")
# Out:
#                  type                                           features
# 0   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 1   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 2   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 3   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 4   FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# ..                ...                                                ...
# 83  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 84  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 85  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 86  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
# 87  FeatureCollection  {'type': 'Feature', 'geometry': {'type': 'Mult...
#
# [88 rows x 2 columns]

# %%
# we won't use this one either

# %%
# in the end we will only use listings and detailed listings--

# %%
import sqlalchemy as sa

con = sa.create_engine("sqlite:///DatosValencia/airbnbValencia.db")

# %%
# don't create it yet until you do an operation on it

# %%
listings.to_sql("listings", con = con, if_exists= "replace")
# Out:
# 9596

# %%
listings_det.to_sql("listings_det", con = con, if_exists = "replace")
# Out:
# 9596
